# %%
pip install deepface
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 39.3 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116952 sha256=6879ad1bc8220db53323f99104510a8e5ee9aabb1e043ecbd660fc42849ef4da
#   Stored in directory: /root/.cache/pip/wheels/f7/f1/89/b9ea2bf8f80ec027a88fef1d354b3816b4d3d29530988972f6
# Successfully built fire
# ...

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
img1=cv2.imread('/content/Screenshot 2023-04-13 at 4.15.49 PM.png')
img2=cv2.imread('/content/Screenshot 2023-04-13 at 10.35.46 AM.png')
img3=cv2.imread('/content/Screenshot 2023-04-13 at 10.36.33 AM.png')
img4=cv2.imread('/content/Screenshot 2023-04-13 at 10.36.57 AM.png')
img5=cv2.imread('/content/Screenshot 2023-04-13 at 10.31.38 AM.png')

# %%
plt.imshow(img1[:,:,::-1])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.imshow(img2[:,:,::-1])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.imshow(img3[:,:,::-1])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.imshow(img4[:,:,::-1])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.imshow(img5[:,:,::-1])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
result_1 = DeepFace.analyze(img1, actions = ['emotion'])
print(result_1)
# Out:
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 14.32it/s]
# [{'emotion': {'angry': 1.5638042241334915, 'disgust': 0.00018409925814921735, 'fear': 10.395082086324692, 'happy': 0.0015047834494907875, 'sad': 38.15448880195618, 'surprise': 0.003876631672028452, 'neutral': 49.88106191158295}, 'dominant_emotion': 'neutral', 'region': {'x': 262, 'y': 144, 'w': 156, 'h': 156}}]

# %%
result_2 = DeepFace.analyze(img2, actions = ['emotion'])
print(result_2)
# Out:
# ...
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00,  9.47it/s]
# [{'emotion': {'angry': 0.05000143428333104, 'disgust': 4.2160212387898355e-05, 'fear': 0.32768500968813896, 'happy': 0.00011424639296819805, 'sad': 98.64505529403687, 'surprise': 5.7645308970677434e-05, 'neutral': 0.9770420379936695}, 'dominant_emotion': 'sad', 'region': {'x': 291, 'y': 137, 'w': 246, 'h': 246}}, {'emotion': {'angry': 0.224347123278506, 'disgust': 7.537283421494926e-11, 'fear': 55.93281721668346, 'happy': 0.013948114896360183, 'sad': 29.1932868476681, 'surprise': 0.0057408160284741095, 'neutral': 14.629867054812136}, 'dominant_emotion': 'fear', 'region': {'x': 212, 'y': 753, 'w': 57, 'h': 57}}]

# %%
result_3 = DeepFace.analyze(img3, actions = ['emotion'])
print(result_3)
# Out:
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 14.26it/s]
# [{'emotion': {'angry': 0.008591241930844262, 'disgust': 5.025689802096167e-05, 'fear': 3.162110596895218, 'happy': 1.9298890605568886, 'sad': 94.64356303215027, 'surprise': 0.00038861699067638256, 'neutral': 0.2554110251367092}, 'dominant_emotion': 'sad', 'region': {'x': 216, 'y': 80, 'w': 135, 'h': 135}}]

# %%
result_4 = DeepFace.analyze(img4, actions = ['emotion'])
print(result_4)
# Out:
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 14.26it/s]
# [{'emotion': {'angry': 0.00105721110230661, 'disgust': 6.960942171524258e-13, 'fear': 0.003758734237635508, 'happy': 0.000315783131554781, 'sad': 3.2717783004045486, 'surprise': 1.2307376229259148e-07, 'neutral': 96.72309160232544}, 'dominant_emotion': 'neutral', 'region': {'x': 132, 'y': 120, 'w': 167, 'h': 167}}]

# %%
result_5 = DeepFace.analyze(img5, actions = ['emotion'])
print(result_5)
# Out:
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 13.92it/s]
# [{'emotion': {'angry': 88.5555200907898, 'disgust': 0.0012968226519556713, 'fear': 0.12346431184719872, 'happy': 0.0005542943984676073, 'sad': 4.436243962421654, 'surprise': 8.288996372631923e-09, 'neutral': 6.882916056091551}, 'dominant_emotion': 'angry', 'region': {'x': 332, 'y': 137, 'w': 169, 'h': 169}}]
